# %%
import pandas as pd

# %% [markdown]
# ### Subindo o dataset bruto

# %%
df=pd.read_csv("caso_full.csv")
df.head() #mostra as 5 primeiras linhas
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 1         NaN            12.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 3         NaN            12.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# 0                         3                                        0.72566
# 1                         3                                        0.33539
# 2                         3                                        0.72566
# 3                         3                                        0.33539
# 4                         4                                        0.96754
#
#   last_available_date  last_available_death_rate  last_available_deaths  \
# 0          2020-03-17                        0.0                      0
# 1          2020-03-17                        0.0                      0
# 2          2020-03-18                        0.0                      0
# 3          2020-03-18                        0.0                      0
# 4          2020-03-19                        0.0                      0
#
#    order_for_place place_type state  new_confirmed  new_deaths
# 0                1       city    AC              3           0
# 1                1      state    AC              3           0
# 2                2       city    AC              0           0
# 3                2      state    AC              0           0
# 4                3       city    AC              1           0

# %%
df['state'].value_counts() #contando quantas ocorrencias tem de cada estado
# Out:
# MG    334547
# SP    267116
# RS    195500
# BA    170019
# PR    159806
# SC    121188
# GO     97341
# PB     90846
# MA     90330
# PI     89238
# CE     79468
# PE     79014
# RN     69504
# PA     61742
# MT     56811
# TO     56430
# AL     42896
# RJ     41038
# ES     34474
# MS     31897
# SE     31567
# AM     26917
# RO     22214
# AC      9687
# RR      7287
# AP      7284
# DF      1391
# Name: state, dtype: int64

# %%
df.loc[df['city'].isnull()]
df=df.dropna()#limpando a planilha das linhas nulas que são referentes aos estados

# %%
df.to_csv('casos_full_sem_nan.csv')

# %%
df['state'].value_counts() #contando quantas ocorrencias tem de cada estado
# Out:
# MG    328151
# SP    265451
# RS    193935
# BA    166540
# PR    158278
# SC    119670
# GO     95507
# PB     89858
# MA     89588
# PI     88561
# CE     78478
# PE     77980
# RN     68500
# PA     60834
# MT     55851
# TO     54128
# AL     41944
# RJ     40031
# ES     33103
# MS     31245
# SE     31066
# AM     26353
# RO     21271
# AC      9182
# AP      6827
# RR      6398
# DF       470
# Name: state, dtype: int64

# %% [markdown]
# ### Filtrando pelo estado de SP e criando um novo DF

# %%
sp=df.loc[df['state']=='SP']
sp.head()
# Out:
#               city  city_ibge_code        date  epidemiological_week  \
# 1952006  São Paulo       3550308.0  2020-02-25                202009
# 1952007        NaN            35.0  2020-02-25                202009
# 1952008  São Paulo       3550308.0  2020-02-26                202009
# 1952009        NaN            35.0  2020-02-26                202009
# 1952010  São Paulo       3550308.0  2020-02-27                202009
#
#          estimated_population  estimated_population_2019  is_last  \
# 1952006            12325232.0                 12252023.0    False
# 1952007            46289333.0                 45919049.0    False
# 1952008            12325232.0                 12252023.0    False
# 1952009            46289333.0                 45919049.0    False
# 1952010            12325232.0                 12252023.0    False
#
#          is_repeated  last_available_confirmed  \
# 1952006        False                         1
# 1952007        False                         1
# 1952008        False                         1
# 1952009        False                         1
# 1952010        False                         1
#
#          last_available_confirmed_per_100k_inhabitants last_available_date  \
# 1952006                                        0.00811          2020-02-25
# 1952007                                        0.00216          2020-02-25
# 1952008                                        0.00811          2020-02-26
# 1952009                                        0.00216          2020-02-26
# 1952010                                        0.00811          2020-02-27
#
#          last_available_death_rate  last_available_deaths  order_for_place  \
# 1952006                        0.0                      0                1
# 1952007                        0.0                      0                1
# 1952008                        0.0                      0                2
# 1952009                        0.0                      0                2
# 1952010                        0.0                      0                3
#
#         place_type state  new_confirmed  new_deaths
# 1952006       city    SP              1           0
# 1952007      state    SP              1           0
# 1952008       city    SP              0           0
# 1952009      state    SP              0           0
# 1952010       city    SP              0           0

# %%
sp_estado=sp.loc[sp['city'].isnull()]# pegando as linhas que sereferem somente ao estado de São Paulo
sp=sp.dropna()# tirando as linhas nulas.

# %%
sp.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'order_for_place',
#        'place_type', 'state', 'new_confirmed', 'new_deaths'],
#       dtype='object')

# %%
sp.drop('is_last', axis=1, inplace=True)
sp.drop('is_repeated', axis=1, inplace = True)
sp.drop('order_for_place', axis=1, inplace = True)
sp.drop('place_type', axis=1, inplace = True)

# %%
sp.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019',
#        'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'state',
#        'new_confirmed', 'new_deaths'],
#       dtype='object')

# %% [markdown]
# ### fazendo duas planilhas para fazer o join depois

# %%
planilha1=sp.groupby('city').agg({'new_deaths': ['sum'], 'epidemiological_week': ['count'],'city_ibge_code': ['first'],'new_confirmed':['sum'],'city':['first'],'estimated_population_2019':['first']})
planilha1.head()
# Out:
#            new_deaths epidemiological_week city_ibge_code new_confirmed  \
#                   sum                count          first           sum
# city
# Adamantina         94                  434      3500105.0          3111
# Adolfo             13                  416      3500204.0           497
# Aguaí              86                  422      3500303.0          2778
# Agudos             82                  444      3500709.0          3570
# Alambari           10                  430      3500758.0           509
#
#                   city estimated_population_2019
#                  first                     first
# city
# Adamantina  Adamantina                   35068.0
# Adolfo          Adolfo                    3562.0
# Aguaí            Aguaí                   36305.0
# Agudos          Agudos                   37214.0
# Alambari      Alambari                    6025.0

# %%
planilha1.rename({'sum': 'new_deaths','count': 'epidemiological_week', 'first': 'city_ibge_code','sum':'new_confirmed','first': 'city' ,'first':'estimated_population_2019'}, axis=1)
# Out:
#                       new_deaths epidemiological_week  \
#                    new_confirmed epidemiological_week
# city
# Adamantina                    94                  434
# Adolfo                        13                  416
# Aguaí                         86                  422
# Agudos                        82                  444
# Alambari                      10                  430
# ...                          ...                  ...
# Águas de São Pedro             7                  436
# Álvares Florence              13                  387
# Álvares Machado               53                  418
# Álvaro de Carvalho             9                  407
# Óleo                           1                  366
#
#                               city_ibge_code new_confirmed  \
#                    estimated_population_2019 new_confirmed
# city
# Adamantina                         3500105.0          3111
# Adolfo                             3500204.0           497
# Aguaí                              3500303.0          2778
# Agudos                             3500709.0          3570
# Alambari                           3500758.0           509
# ...                                      ...           ...
# Águas de São Pedro                 3500600.0           298
# Álvares Florence                   3501202.0           449
# Álvares Machado                    3501301.0          1824
# Álvaro de Carvalho                 3501400.0           149
# Óleo                               3533809.0            93
#
#                                         city estimated_population_2019
#                    estimated_population_2019 estimated_population_2019
# city
# Adamantina                        Adamantina                   35068.0
# Adolfo                                Adolfo                    3562.0
# Aguaí                                  Aguaí                   36305.0
# Agudos                                Agudos                   37214.0
# Alambari                            Alambari                    6025.0
# ...                                      ...                       ...
# Águas de São Pedro        Águas de São Pedro                    3451.0
# Álvares Florence            Álvares Florence                    3679.0
# Álvares Machado              Álvares Machado                   24915.0
# Álvaro de Carvalho        Álvaro de Carvalho                    5227.0
# Óleo                                    Óleo                    2496.0
#
# [645 rows x 6 columns]

# %%
planilha1.head()
# Out:
#            new_deaths epidemiological_week city_ibge_code new_confirmed  \
#                   sum                count          first           sum
# city
# Adamantina         94                  434      3500105.0          3111
# Adolfo             13                  416      3500204.0           497
# Aguaí              86                  422      3500303.0          2778
# Agudos             82                  444      3500709.0          3570
# Alambari           10                  430      3500758.0           509
#
#                   city estimated_population_2019
#                  first                     first
# city
# Adamantina  Adamantina                   35068.0
# Adolfo          Adolfo                    3562.0
# Aguaí            Aguaí                   36305.0
# Agudos          Agudos                   37214.0
# Alambari      Alambari                    6025.0

# %% [markdown]
# ### transformando em os dataframes em csv

# %%
planilha1.to_csv('cidades_sp_agrupadas.csv')

# %%
sp.to_csv('covid_municipios_sp.csv')
sp_estado.to_csv('covid_estado_sp.csv')
mortes_semana.to_csv('mortes_semana.csv')
