# %%
import pandas as pd

# %%
df=pd.read_csv("caso_full.csv")
df
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 2275547      Tupirama       1721257.0  2021-06-19                202124
# 2275548    Tupiratins       1721307.0  2021-06-19                202124
# 2275549  Wanderlândia       1722081.0  2021-06-19                202124
# 2275550       Xambioá       1722107.0  2021-06-19                202124
# 2275551           NaN            17.0  2021-06-19                202124
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
df['state'].value_counts()
# Out:
# MG    334547
# SP    267116
# RS    195500
# BA    170019
# PR    159806
# SC    121188
# GO     97341
# PB     90846
# MA     90330
# PI     89238
# CE     79468
# PE     79014
# RN     69504
# PA     61742
# MT     56811
# TO     56430
# AL     42896
# RJ     41038
# ES     34474
# MS     31897
# SE     31567
# AM     26917
# RO     22214
# AC      9687
# RR      7287
# AP      7284
# DF      1391
# Name: state, dtype: int64

# %%
sp=df.loc[df['state']=='SP']
sp
# Out:
#                        city  city_ibge_code        date  epidemiological_week  \
# 1952006           São Paulo       3550308.0  2020-02-25                202009
# 1952007                 NaN            35.0  2020-02-25                202009
# 1952008           São Paulo       3550308.0  2020-02-26                202009
# 1952009                 NaN            35.0  2020-02-26                202009
# 1952010           São Paulo       3550308.0  2020-02-27                202009
# ...                     ...             ...         ...                   ...
# 2219117    Álvares Florence       3501202.0  2021-06-19                202124
# 2219118     Álvares Machado       3501301.0  2021-06-19                202124
# 2219119  Álvaro de Carvalho       3501400.0  2021-06-19                202124
# 2219120                Óleo       3533809.0  2021-06-19                202124
# 2219121                 NaN            35.0  2021-06-19                202124
#
# ...

# %%
df.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 1         NaN            12.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 3         NaN            12.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 1              894470.0                   881935.0    False        False
# 2              413418.0                   407319.0    False        False
# 3              894470.0                   881935.0    False        False
# 4              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
df.to_csv('casos_full_sem_nan.csv')

# %%
df.loc[df['city'].isnull()]
df=df.dropna()

# %%
df.head()
# Out:
#          city  city_ibge_code        date  epidemiological_week  \
# 0  Rio Branco       1200401.0  2020-03-17                202012
# 2  Rio Branco       1200401.0  2020-03-18                202012
# 4  Rio Branco       1200401.0  2020-03-19                202012
# 6  Rio Branco       1200401.0  2020-03-20                202012
# 8  Rio Branco       1200401.0  2020-03-21                202012
#
#    estimated_population  estimated_population_2019  is_last  is_repeated  \
# 0              413418.0                   407319.0    False        False
# 2              413418.0                   407319.0    False        False
# 4              413418.0                   407319.0    False        False
# 6              413418.0                   407319.0    False        False
# 8              413418.0                   407319.0    False        False
#
#    last_available_confirmed  last_available_confirmed_per_100k_inhabitants  \
# ...

# %%
sp['new_deaths'].sum() #nesse valor tem que tirar os nulos, que são o do estado.
# Out:
# 243198

# %%
sp=sp.dropna()

# %%
sp
# Out:
#                        city  city_ibge_code        date  epidemiological_week  \
# 1952006           São Paulo       3550308.0  2020-02-25                202009
# 1952008           São Paulo       3550308.0  2020-02-26                202009
# 1952010           São Paulo       3550308.0  2020-02-27                202009
# 1952012           São Paulo       3550308.0  2020-02-28                202009
# 1952014           São Paulo       3550308.0  2020-02-29                202009
# ...                     ...             ...         ...                   ...
# 2219116  Águas de São Pedro       3500600.0  2021-06-19                202124
# 2219117    Álvares Florence       3501202.0  2021-06-19                202124
# 2219118     Álvares Machado       3501301.0  2021-06-19                202124
# 2219119  Álvaro de Carvalho       3501400.0  2021-06-19                202124
# 2219120                Óleo       3533809.0  2021-06-19                202124
#
# ...

# %%
sp.head(
)
# Out:
# <AxesSubplot:>

# %%
sp.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'order_for_place',
#        'place_type', 'state', 'new_confirmed', 'new_deaths'],
#       dtype='object')

# %%
sp.head()
# Out:
#               city  city_ibge_code        date  epidemiological_week  \
# 1952006  São Paulo       3550308.0  2020-02-25                202009
# 1952008  São Paulo       3550308.0  2020-02-26                202009
# 1952010  São Paulo       3550308.0  2020-02-27                202009
# 1952012  São Paulo       3550308.0  2020-02-28                202009
# 1952014  São Paulo       3550308.0  2020-02-29                202009
#
#          estimated_population  estimated_population_2019  is_last  \
# 1952006            12325232.0                 12252023.0    False
# 1952008            12325232.0                 12252023.0    False
# 1952010            12325232.0                 12252023.0    False
# 1952012            12325232.0                 12252023.0    False
# 1952014            12325232.0                 12252023.0    False
#
#          is_repeated  last_available_confirmed  \
# 1952006        False                         1
# 1952008        False                         1
# ...

# %%
tabela_agrupada= sp[['city_ibge_code','new_confirmed','city', 'new_deaths']].groupby(sp['estimated_population_2019']).sum()
tabela_agrupada
# Out:
#                            city_ibge_code  new_confirmed  new_deaths
# estimated_population_2019
# 837.0                        1.339754e+09            105           1
# 1165.0                       1.457919e+09            143           3
# 1267.0                       1.338957e+09             56           3
# 1464.0                       1.272722e+09            115           4
# 1487.0                       1.379863e+09             43           2
# ...                                   ...            ...         ...
# 721944.0                     1.629406e+09          78964        1632
# 838936.0                     1.635954e+09          65418        2787
# 1204073.0                    1.610861e+09          89856        3560
# 1379182.0                    1.618648e+09          56419        4160
# 12252023.0                   1.707698e+09         828737       32414
#
# [642 rows x 3 columns]

# %%
tabela_agrupada.to_csv('tabela_agrupada.csv')

# %%
mg=df.loc[df['state']=='MG']
mg['new_deaths'].sum()
# Out:
# 88415

# %%
am=df.loc[df['state']=='AM']
am['new_deaths'].sum()
# Out:
# 26423

# %%
sp.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'order_for_place',
#        'place_type', 'state', 'new_confirmed', 'new_deaths'],
#       dtype='object')

# %%
mortes_semana = sp_estado[['new_deaths', 'epidemiological_week','city_ibge_code','new_confirmed']].groupby(['epidemiological_week']).sum()
mortes_semana
# Out:
#                       new_deaths  city_ibge_code  new_confirmed
# epidemiological_week
# 202009                         0           175.0              2
# 202010                         0           245.0             11
# 202011                         0           245.0             52
# 202012                        15           245.0            331
# 202013                        69           245.0           1010
# ...                          ...             ...            ...
# 202120                      3502           245.0          95305
# 202121                      3626           245.0          74298
# 202122                      3069           245.0         100308
# 202123                      3695           245.0          94376
# 202124                      4073           245.0         123633
#
# [69 rows x 3 columns]

# %%
sp.to_csv('covid_sp.csv')

# %%
sp.shape
# Out:
# (265451, 18)

# %%
vacinas = pd.read_csv('20210619_percentual_primeira_dose.csv',sep=';')
vacinas
# Out:
#                Município  Rank of % da população geral % da população geral  \
# 0               BOTUCATU                             1          0,791547965
# 1                SERRANA                             2          0,741411796
# 2              TURMALINA                             3          0,653891509
# 3             FLORA RICA                             4          0,638461538
# 4                    URU                             5          0,616652212
# ..                   ...                           ...                  ...
# 640               PONTAL                           641          0,172244946
# 641  RIO GRANDE DA SERRA                           642          0,171241932
# 642    PALMARES PAULISTA                           643          0,170028177
# 643                IPERÓ                           644          0,163365293
# 644             BALBINOS                           645          0,147623862
#
#      População
# 0       148130
# 1        45644
# ...

# %%
mortes_dia = sp_estado[['new_deaths', 'date','city_ibge_code','new_confirmed']].groupby(['date']).sum()
mortes_dia
# Out:
#             new_deaths  city_ibge_code  new_confirmed
# date
# 2020-02-25           0            35.0              1
# 2020-02-26           0            35.0              0
# 2020-02-27           0            35.0              0
# 2020-02-28           0            35.0              1
# 2020-02-29           0            35.0              0
# ...                ...             ...            ...
# 2021-06-15         897            35.0          23227
# 2021-06-16         795            35.0          22582
# 2021-06-17         619            35.0          15054
# 2021-06-18         714            35.0          27706
# 2021-06-19         722            35.0          20483
#
# [481 rows x 3 columns]

# %%
mortes_dia.to_csv('mortes_dia.csv')

# %%
taxa_morte.to_csv('taxa_morte.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-abb927f91db3> in <module>
# ----> 1 taxa_morte.to_csv('taxa_morte.csv')
#
# NameError: name 'taxa_morte' is not defined

# %%
araraquara=sp.loc[sp['city']=='Araraquara'].groupby('date').sum()
araraquara

# %%
araraquara.to_csv('araraquara.csv')

# %%
botucatu = sp.loc[sp['city']=='Botucatu'].groupby('date').sum()
botucatu

# %%
botucatu.to_csv('botucatu.csv')

# %%
serrana= sp.loc[sp['city']=='Serrana'].groupby('date').sum()
serrana

# %%
serrana.to_csv('serrana.csv')

# %%
vacinas.head(10)

# %%
percentual_primeira=csv_read

# %%
taxa_morte= sp.groupby
