# %%
import pandas as pd

# %%
df=pd.read_csv('caso_full.csv')
df
# Out:
#                  city  city_ibge_code        date  epidemiological_week  \
# 0          Rio Branco       1200401.0  2020-03-17                202012
# 1                 NaN            12.0  2020-03-17                202012
# 2          Rio Branco       1200401.0  2020-03-18                202012
# 3                 NaN            12.0  2020-03-18                202012
# 4          Rio Branco       1200401.0  2020-03-19                202012
# ...               ...             ...         ...                   ...
# 2264315      Tupirama       1721257.0  2021-06-17                202124
# 2264316    Tupiratins       1721307.0  2021-06-17                202124
# 2264317  Wanderlândia       1722081.0  2021-06-17                202124
# 2264318       Xambioá       1722107.0  2021-06-17                202124
# 2264319           NaN            17.0  2021-06-17                202124
#
#          estimated_population  estimated_population_2019  is_last  \
# ...

# %%
df['state'].value_counts()
# Out:
# MG    332837
# SP    265822
# RS    194502
# BA    169181
# PR    159004
# SC    120594
# GO     96845
# PB     90396
# MA     89894
# PI     88788
# CE     79096
# PE     78640
# RN     69166
# PA     61450
# MT     56525
# TO     56150
# AL     42688
# RJ     40850
# ES     34314
# MS     31737
# SE     31415
# AM     26791
# RO     22106
# AC      9641
# RR      7253
# AP      7250
# DF      1385
# Name: state, dtype: int64

# %%
sp=df.loc[df['state']=='SP']
sp
# Out:
#                        city  city_ibge_code        date  epidemiological_week  \
# 1942348           São Paulo       3550308.0  2020-02-25                202009
# 1942349                 NaN            35.0  2020-02-25                202009
# 1942350           São Paulo       3550308.0  2020-02-26                202009
# 1942351                 NaN            35.0  2020-02-26                202009
# 1942352           São Paulo       3550308.0  2020-02-27                202009
# ...                     ...             ...         ...                   ...
# 2208165    Álvares Florence       3501202.0  2021-06-17                202124
# 2208166     Álvares Machado       3501301.0  2021-06-17                202124
# 2208167  Álvaro de Carvalho       3501400.0  2021-06-17                202124
# 2208168                Óleo       3533809.0  2021-06-17                202124
# 2208169                 NaN            35.0  2021-06-17                202124
#
# ...

# %%
 sp_estado=sp.loc[sp['city'].isnull()]# o que fazer com essas linhas?

# %%
sp_estado['new_deaths'].sum() #esse é o valor certo do estado
# Out:
# 120524

# %%
sp['new_deaths'].sum() #nesse valor tem que tirar os nulos, que são o do estado.
# Out:
# 119904

# %%
sp=sp.dropna()

# %%
sp
# Out:
#                        city  city_ibge_code        date  epidemiological_week  \
# 1942348           São Paulo       3550308.0  2020-02-25                202009
# 1942350           São Paulo       3550308.0  2020-02-26                202009
# 1942352           São Paulo       3550308.0  2020-02-27                202009
# 1942354           São Paulo       3550308.0  2020-02-28                202009
# 1942356           São Paulo       3550308.0  2020-02-29                202009
# ...                     ...             ...         ...                   ...
# 2208164  Águas de São Pedro       3500600.0  2021-06-17                202124
# 2208165    Álvares Florence       3501202.0  2021-06-17                202124
# 2208166     Álvares Machado       3501301.0  2021-06-17                202124
# 2208167  Álvaro de Carvalho       3501400.0  2021-06-17                202124
# 2208168                Óleo       3533809.0  2021-06-17                202124
#
# ...

# %%
sp.head()
# Out:
#               city  city_ibge_code        date  epidemiological_week  \
# 1942348  São Paulo       3550308.0  2020-02-25                202009
# 1942350  São Paulo       3550308.0  2020-02-26                202009
# 1942352  São Paulo       3550308.0  2020-02-27                202009
# 1942354  São Paulo       3550308.0  2020-02-28                202009
# 1942356  São Paulo       3550308.0  2020-02-29                202009
#
#          estimated_population  estimated_population_2019  is_last  \
# 1942348            12325232.0                 12252023.0    False
# 1942350            12325232.0                 12252023.0    False
# 1942352            12325232.0                 12252023.0    False
# 1942354            12325232.0                 12252023.0    False
# 1942356            12325232.0                 12252023.0    False
#
#          is_repeated  last_available_confirmed  \
# 1942348        False                         1
# 1942350        False                         1
# ...

# %%
sp.columns
# Out:
# Index(['city', 'city_ibge_code', 'date', 'epidemiological_week',
#        'estimated_population', 'estimated_population_2019', 'is_last',
#        'is_repeated', 'last_available_confirmed',
#        'last_available_confirmed_per_100k_inhabitants', 'last_available_date',
#        'last_available_death_rate', 'last_available_deaths', 'order_for_place',
#        'place_type', 'state', 'new_confirmed', 'new_deaths'],
#       dtype='object')

# %%
# Out:
#                                              Cidades  \
# 0  1942348             São Paulo
# 1942350         ...
#
#                                               Mortes
# 0  1942348    0
# 1942350    0
# 1942352    0
# 1942354...

# %%
sp.groupby(by='epidemiological_week').sum().sort_values('new_deaths')
# Out:
#                       city_ibge_code  estimated_population  \
# epidemiological_week
# 202009                  1.775154e+07            61626160.0
# 202010                  2.839946e+07            86418925.0
# 202011                  6.374101e+07            88265414.0
# 202012                  3.463465e+08           129840263.0
# 202013                  7.244997e+08           164615098.0
# ...                              ...                   ...
# 202118                  1.593207e+10           324025331.0
# 202117                  1.593207e+10           324025331.0
# 202113                  1.593207e+10           324025331.0
# 202114                  1.593207e+10           324025331.0
# 202115                  1.593207e+10           324025331.0
#
#                       estimated_population_2019  is_last  is_repeated  \
# epidemiological_week
# 202009                               61260115.0        0            0
# ...
